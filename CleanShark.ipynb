# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import scr.functions as f

# %%
data = pd.read_csv('./Input/GSAF5.csv', encoding = "cp1252")
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
print(data.shape)
# Out:
# (5992, 24)

# %%
print(data.columns)
print(data.dtypes)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# ...

# %%
null_cols = data.isnull().sum()
null_cols
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Los surferos son los que mas ataques de tiburon sufren

# %%
#data.describe()

# %%
#data.T.head()

# %%
data["Year"].value_counts().head(50)
data = data.drop(data[data["Year"]==0].index)
data = data.drop(data[data["Year"]==5].index)
data = data.drop(data[data["Year"]<=1950].index)
data["Year"].value_counts().head(50)
set(data["Year"])
len((data["Year"]))
# Out:
# 4228

# %%
a=set(data["Country"])
a
# Out:
# {' TONGA',
#  'ADMIRALTY ISLANDS',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BANGLADESH',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COSTA RICA',
#  'CROATIA',
#  'CUBA',
#  'DIEGO GARCIA',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'FEDERATED STATES OF MICRONESIA',
#  'FIJI',
#  'FRANCE',
#  'FRENCH POLYNESIA',
#  'Fiji',
#  'GABON',
#  'GRAND CAYMAN',
#  'GREECE',
#  'GRENADA',
#  'GUAM',
#  'GUATEMALA',
#  'GULF OF ADEN',
#  'HONDURAS',
#  'HONG KONG',
#  'INDIA',
#  'INDIAN OCEAN',
#  'INDONESIA',
#  'IRAN',
#  'IRAQ',
#  'ISRAEL',
#  'ITALY',
#  'JAMAICA',
#  'JAPAN',
#  'JOHNSTON ISLAND',
# ...

# %%
"""b=set(data['Area'])
len(b)
b"""
# Out:
# "b=set(data['Area'])\nlen(b)\nb"

# %%
import re

# %%
"""data["Area"].astype(str)"""
# Out:
# 'data["Area"].astype(str)'

# %%
drop_cols = list(null_cols[null_cols > 5989].index)
data = data.drop(drop_cols, axis=1)

# %%
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# ...

# %%
set(data["Type"])
# Out:
# {'Boat', 'Boating', 'Invalid', 'Provoked', 'Sea Disaster', 'Unprovoked'}

# %%
set(data["Sex "])
# Out:
# {'F', 'M', 'M ', 'lli', nan}

# %%
#set(data["Name"])

# %%
data["Country"]=data["Country"].astype(str)
data["Country"]
#h=[]
#for e in a:
    #if re.match("UNITED ARAB EMIRATES \(UAE\)",e):
        #j = re.sub("UNITED ARAB EMIRATES \(UAE\)","UNITED ARAB EMIRATES",e)
        #h.append(j)
    #else:
        #a = e.strip()
        #h.append(a)
# Out:
# 0                USA
# 1                USA
# 2                USA
# 3          AUSTRALIA
# 4          AUSTRALIA
#             ...
# 4223       AUSTRALIA
# 4224       AUSTRALIA
# 4225    SOUTH AFRICA
# 4226       AUSTRALIA
# 4227      NEW GUINEA
# Name: Country, Length: 4228, dtype: object

# %%
"""set(h)
h.sort()
print(h)
print(len(h))
r=set(h)
print(len(r))"""
# Out:
# 'set(h)\nh.sort()\nprint(h)\nprint(len(h))\nr=set(h)\nprint(len(r))'

# %%
h=[]
for e in data["Country"]:
    if re.match("UNITED ARAB EMIRATES \(UAE\)",e):
        j = re.sub("UNITED ARAB EMIRATES \(UAE\)","UNITED ARAB EMIRATES",e)
        h.append(j)
    elif re.match("ST. MAARTIN",e):
        s = re.sub("ST. MAARTIN","ST. MARTIN",e)
        h.append(s)
    elif re.search("\?",e):
        g = re.sub("\?","",e)
        h.append(g)
    elif re.search("Fiji",e):
        g = re.sub("Fiji","FIJI",e)
        h.append(g)
    else:
        a = e.strip("?")
        a = e.strip()
        h.append(a)
data["Country"]=h
len(set(h))
# Out:
# 140

# %%
data = data.drop(data[data["Country"]=='nan'].index)
data = data.drop(data[data["Country"]=='Between PORTUGAL & INDIA'].index)
print(len(data))
print(len(data["Country"]))
set(data["Country"])
# Out:
# 4215
# 4215
# {'ADMIRALTY ISLANDS',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BANGLADESH',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COSTA RICA',
#  'CROATIA',
#  'CUBA',
#  'DIEGO GARCIA',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'FEDERATED STATES OF MICRONESIA',
#  'FIJI',
#  'FRANCE',
#  'FRENCH POLYNESIA',
#  'GABON',
#  'GRAND CAYMAN',
#  'GREECE',
#  'GRENADA',
#  'GUAM',
#  'GUATEMALA',
#  'GULF OF ADEN',
#  'HONDURAS',
#  'HONG KONG',
#  'INDIA',
#  'INDIAN OCEAN',
#  'INDONESIA',
#  'IRAN',
#  'IRAQ',
#  'ISRAEL',
#  'ITALY',
#  'JAMAICA',
#  'JAPAN',
#  'JOHNSTON ISLAND',
#  'KENYA',
# ...

# %%
"""print(set(h))
len(set(h))
set(h)"""
# Out:
# 'print(set(h))\nlen(set(h))\nset(h)'

# %%
data["Country"].value_counts()
# Out:
# USA                       1771
# AUSTRALIA                  731
# SOUTH AFRICA               450
# PAPUA NEW GUINEA           110
# BRAZIL                      95
#                           ...
# RED SEA / INDIAN OCEAN       1
# ARUBA                        1
# HONDURAS                     1
# BRITISH VIRGIN ISLANDS       1
# MAYOTTE                      1
# Name: Country, Length: 139, dtype: int64

# %%
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# ...

# %%
data["Fatal (Y/N)"].value_counts()
# Out:
# N          3403
# Y           747
# UNKNOWN      50
#  N            8
# Name: Fatal (Y/N), dtype: int64

# %%
#set(data["Activity"])

# %%
data["Activity"] = data["Activity"].astype(str)
print(data.dtypes)
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# dtype: object

# %%
data["Activity"].value_counts()
# Out:
# Surfing                                             894
# Swimming                                            512
# Spearfishing                                        312
# nan                                                 308
# Fishing                                             253
#                                                    ...
# Scientific research (Dr. Sonny Gruber's student)      1
# Placed hand in disemboweled shark’s jaws              1
# Fishing, holding fish                                 1
# Air/Sea Disaster                                      1
# Swimming after his canoe capsized                     1
# Name: Activity, Length: 933, dtype: int64

# %%
null_cols = data["Activity"].isnull().sum()
null_cols
# Out:
# 0

# %%
dataActClean=[]
for e in data["Activity"]:
    if re.search("Surf|surf",e):
        a = e.strip()
        s = a.replace(a,"Surfing")
        dataActClean.append(s)
    elif re.search("Disaster|Aircraft|aircraft|disaster|tsunami|storm|Wreck|wreck|Accident|accident|explo|Explo|Adrift|sank|foundered|capsized|burning|fog|crash|plunged|Foundering|fell|Fell|overboard|drift|shot down|rescue|aid|sunk|Sink|Hurricane|hurricane|squall|plane|feet|skiing|submarine|saving|Parachuted|down|steam|wave",e):
        a = e.strip()
        s = a.replace(a,"Accidents or natural disasters")
        dataActClean.append(s)
    elif re.search("Playing|Canoe|canoe|kite|Kite|race|Race|Racing|racing|Competing|kayak|Kayak|Scuba|dived|Dived|diver|diving|Diver|Diving|Snorkel|Paddl|Rowing|Bodyboarding|Body|body|paddl|Boogie|Scull",e):
        a = e.strip()
        s = a.replace(a,"Other Water Sports")
        dataActClean.append(s)
    elif re.search("Swimming|swimming",e):
        a = e.strip()
        s = a.replace(a,"Swimming")
        dataActClean.append(s)
    elif re.search("Fishing|fishing|Lobstering|Crabbing|crabbing|Killing|Harpoon|harpoon|Catching|Collecting|Hunting|Net|net|Fish|fish|Clamming",e):
        a = e.strip()
        s = a.replace(a,"Fishing&Hunting")
        dataActClean.append(s)
    elif re.search("Walking|walking",e):
        a = e.strip()
        s = a.replace(a,"Walking")
        dataActClean.append(s)
    elif re.search("Bathing|bathing|Floating|Standing|standing|Bather|Splash|splash|jump|Jump|Treading|Beach|beach|Sitting|water|float|Wading|wading",e):
        a = e.strip()
        s = a.replace(a,"Bathing")
        dataActClean.append(s)
    elif re.search("Attempting|attempting|Escaping|horse|religious",e):
        a = e.strip()
        s = a.replace(a,"Stranger things")
        dataActClean.append(s)
    elif re.search("Shark|shark",e):
        a = e.strip()
        s = a.replace(a,"Shark related activities")
        dataActClean.append(s)
    elif re.search("Boat|boat|Boating|boating|Sailing|sailing|Cruising|raft",e):
        a = e.strip()
        s = a.replace(a,"Boating")
        dataActClean.append(s)
    elif re.search("Murder|Disappeared|disappeared|found|Unknown|male|nan|miss|details|\.",e):
        a = e.strip()
        s = a.replace(a,"UnKnown")
        dataActClean.append(s)
    else:
        a = e.strip()
        s = a.replace(a,"Random activities")
        dataActClean.append(s)
#print(dataActClean)
print(len(set(dataActClean)))
set(dataActClean)
data["New"] = dataActClean
len(dataActClean)
print(len(data["Activity"]))
len(dataActClean)
set(dataActClean)
# Out:
# 12
# 4215
# {'Accidents or natural disasters',
#  'Bathing',
#  'Boating',
#  'Fishing&Hunting',
#  'Other Water Sports',
#  'Random activities',
#  'Shark related activities',
#  'Stranger things',
#  'Surfing',
#  'Swimming',
#  'UnKnown',
#  'Walking'}

# %%
data["New"].value_counts().head(25)
# Out:
# Surfing                           1142
# Fishing&Hunting                    792
# Other Water Sports                 706
# Swimming                           604
# UnKnown                            322
# Bathing                            321
# Accidents or natural disasters     187
# Shark related activities            47
# Random activities                   41
# Boating                             22
# Walking                             16
# Stranger things                     15
# Name: New, dtype: int64

# %%
set(data["Date"])
# Out:
# {'22-Sep-68',
#  '07-Jun-06',
#  '06-May-72',
#  '19-Jul-2007.b',
#  '18-Oct-00',
#  '20-Jun-12',
#  '19-Aug-67',
#  '10-Jun-62',
#  'Reported 02-Jun-1958',
#  '31-Mar-88',
#  '13-Apr-57',
#  '16-Apr-91',
#  '19-Aug-01',
#  '15-Mar-98',
#  '07-Sep-74',
#  '04-Apr-70',
#  '30-Jul-09',
#  '28-Jul-56',
#  '12-Apr-55',
#  '08-Mar-01',
#  'Reported 14-Feb-1975',
#  '21-Jul-76',
#  'May-68',
#  '31-Oct-64',
#  '25-Jan-06',
#  '13-Jun-82',
#  '26-Apr-77',
#  '12-Mar-76',
#  '15-Jun-10',
#  '1999',
#  '14-Dec-08',
#  '04-Jan-64',
#  '03-Feb-10',
#  '28-Nov-59',
#  '19-Nov-14',
#  '1989',
#  '23-Feb-75',
#  'Reported 11-Apr-1968',
#  ' 01-Sep-2013',
#  '25-Dec-64',
#  '24-Dec-98',
#  '14-May-03',
#  'Jul-86',
#  '07-Jun-60',
#  '14-Oct-72',
#  '15-Jun-06',
#  '29-Jun-54',
#  '24-Feb-57',
#  '22-Sep-62',
#  ' 14-Sep-2013',
#  '28-Sep-85',
#  '05-Aug-02',
#  '13-Dec-87',
#  '30-Sep-95',
#  'Mid Aug-1966',
#  '15-Aug-87',
#  '27-Jun-54',
#  'Reported      10-Nov-1983',
#  '21-Dec-51',
# ...

# %%
data["Date"].value_counts()
meses = []
for e in data["Date"]:
    if re.search("\d{2}-[JFMAMSOND][a-z]+",e):
        a = e.strip()
        s = re.sub("\d{2}-","",a)
        s = re.sub("-\d{2}","",s)
        s = re.sub("Reported ","",s)
        s = re.sub("\d{1,2}","",s)
        s = re.sub("\.|\-|\"","",s)
        s = re.sub("Before|Between|Anniversary Day|or|&|Letter dated|Repted","",s)
        s = re.sub("Ap$|April","Apr",s)
        s = re.sub("Decp","Dec",s)
        s = re.sub("Feb\s\w+","Feb",s)
        s = re.sub("Mar.+","Mar",s)
        s = re.sub("Aug.+","Aug",s)
        s = re.sub("^\w.+[J].+|Jul.+","Jul",s)
        s = re.sub("Nov.+","Nov",s)
        s = re.sub("Oct.+","Oct",s)
        s = re.sub("Sep.+","Sep",s)
        s = re.sub("\w.+[Sep]","Sep",s)
        s=s.strip()
        meses.append(s)
    else:
        meses.append(s)
print(len(set(meses)))
set(meses)
# Out:
# 12
# {'Apr',
#  'Aug',
#  'Dec',
#  'Feb',
#  'Jan',
#  'Jul',
#  'Jun',
#  'Mar',
#  'May',
#  'Nov',
#  'Oct',
#  'Sep'}

# %%
"""data["Date"].value_counts()
meses = []
for e in data["Date"]:
    if re.search("-[JFMAMSOND][a-z]{2}",e):
        s = re.findall("-[JFMAMSOND][a-z]{2}",e)
        for i in s:
            i = re.sub("-","",i)
            meses.append(i)
    else:
        meses.append("Unknown")"""
print(len((meses)))
set(meses)
data["holaaa"]=meses
data4 = data["holaaa"]
data4.value_counts()
# Out:
# 4215
# Jan    498
# Jul    468
# Aug    441
# Sep    409
# Jun    364
# Oct    327
# Apr    313
# Dec    300
# Mar    285
# May    276
# Nov    270
# Feb    264
# Name: holaaa, dtype: int64

# %%
data4 = data4.drop(data4[data["holaaa"]=='Jut'].index)
len(data4)
# Out:
# 4215

# %%
print(data4.value_counts())
print(len(set((data4))))
# Out:
# Jan    498
# Jul    468
# Aug    441
# Sep    409
# Jun    364
# Oct    327
# Apr    313
# Dec    300
# Mar    285
# May    276
# Nov    270
# Feb    264
# Name: holaaa, dtype: int64
# 12

# %%
data["Activity"]=dataActClean
data["Date"]=meses
data
# Out:
#        Case Number Date  Year        Type       Country             Area  \
# 0     2016.09.18.c  Sep  2016  Unprovoked           USA          Florida
# 1     2016.09.18.b  Sep  2016  Unprovoked           USA          Florida
# 2     2016.09.18.a  Sep  2016  Unprovoked           USA          Florida
# 3       2016.09.17  Sep  2016  Unprovoked     AUSTRALIA         Victoria
# 4       2016.09.15  Sep  2016  Unprovoked     AUSTRALIA         Victoria
# ...            ...  ...   ...         ...           ...              ...
# 4223    1951.02.03  Feb  1951  Unprovoked     AUSTRALIA  New South Wales
# 4224    1951.02.01  Feb  1951  Unprovoked     AUSTRALIA  New South Wales
# 4225    1951.01.21  Jan  1951  Unprovoked  SOUTH AFRICA    KwaZulu-Natal
# 4226    1951.01.03  Jan  1951     Invalid     AUSTRALIA  New South Wales
# 4227    1951.00.00  Jan  1951  Unprovoked    NEW GUINEA  Madang Province
#
#                                           Location  Activity             Name  \
# ...

# %%
drop_col = ["Name","Year","Type","original order","Case Number","Sex ","Age","Injury","Time","Location","Species ","pdf","href formula","href","Case Number.1","Case Number.2","Investigator or Source","New","holaaa"]
df = data.drop(drop_col,axis=1)
df
# Out:
#      Date       Country             Area  Activity Fatal (Y/N)
# 0     Sep           USA          Florida   Surfing           N
# 1     Sep           USA          Florida   Surfing           N
# 2     Sep           USA          Florida   Surfing           N
# 3     Sep     AUSTRALIA         Victoria   Surfing           N
# 4     Sep     AUSTRALIA         Victoria   Surfing           N
# ...   ...           ...              ...       ...         ...
# 4223  Feb     AUSTRALIA  New South Wales   Surfing           N
# 4224  Feb     AUSTRALIA  New South Wales  Swimming           N
# 4225  Jan  SOUTH AFRICA    KwaZulu-Natal  Swimming           Y
# 4226  Jan     AUSTRALIA  New South Wales   UnKnown           Y
# 4227  Jan    NEW GUINEA  Madang Province   UnKnown           Y
#
# [4215 rows x 5 columns]

# %%
df.rename(columns={"Date":"Month"}, inplace=True)
df
# Out:
#      Month       Country             Area  Activity Fatal (Y/N)
# 0      Sep           USA          Florida   Surfing           N
# 1      Sep           USA          Florida   Surfing           N
# 2      Sep           USA          Florida   Surfing           N
# 3      Sep     AUSTRALIA         Victoria   Surfing           N
# 4      Sep     AUSTRALIA         Victoria   Surfing           N
# ...    ...           ...              ...       ...         ...
# 4223   Feb     AUSTRALIA  New South Wales   Surfing           N
# 4224   Feb     AUSTRALIA  New South Wales  Swimming           N
# 4225   Jan  SOUTH AFRICA    KwaZulu-Natal  Swimming           Y
# 4226   Jan     AUSTRALIA  New South Wales   UnKnown           Y
# 4227   Jan    NEW GUINEA  Madang Province   UnKnown           Y
#
# [4215 rows x 5 columns]

# %%
x=df.melt(id_vars=["Month",'Country'],value_vars="Activity")
x.head()
display(x)
# Out:
#      Month       Country  variable     value
# 0      Sep           USA  Activity   Surfing
# 1      Sep           USA  Activity   Surfing
# 2      Sep           USA  Activity   Surfing
# 3      Sep     AUSTRALIA  Activity   Surfing
# 4      Sep     AUSTRALIA  Activity   Surfing
# ...    ...           ...       ...       ...
# 4210   Feb     AUSTRALIA  Activity   Surfing
# 4211   Feb     AUSTRALIA  Activity  Swimming
# 4212   Jan  SOUTH AFRICA  Activity  Swimming
# 4213   Jan     AUSTRALIA  Activity   UnKnown
# 4214   Jan    NEW GUINEA  Activity   UnKnown
#
# [4215 rows x 4 columns]

# %%
y=df.groupby(['Month','Country'])['Activity'].value_counts().to_frame()
y = y.rename(columns={"Activity": "Sharks_attacks"})
y["Sharks_attacks"].sum()
y=y.sort_values(by='Sharks_attacks', ascending=False)
y.head(30)
# Out:
#                                     Sharks_attacks
# Month Country   Activity
# Sep   USA       Surfing                        112
# Oct   USA       Surfing                        101
# Aug   USA       Surfing                         81
# Apr   USA       Surfing                         65
# Jul   USA       Surfing                         65
# Nov   USA       Surfing                         57
# Jun   USA       Swimming                        49
# Aug   USA       Other Water Sports              48
# Jul   USA       Swimming                        46
# Jun   USA       Surfing                         46
# May   USA       Surfing                         44
# Aug   USA       Bathing                         42
# Jul   USA       Fishing&Hunting                 39
#                 Bathing                         39
#                 Other Water Sports              38
# Aug   USA       Swimming                        38
# Mar   USA       Surfing                         37
# ...

# %%
y.to_csv("mes_country_activ.csv")

# %%
#Estados Unidos en Septiembre y para surfear es la convinación más peligrosa por los tiburones

# %%
z=df.groupby(['Month'])['Activity'].value_counts().to_frame()
z = z.rename(columns={"Activity": "Sharks_attacks"})
z.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                          Sharks_attacks
# Month Activity
# Sep   Surfing                       138
# Oct   Surfing                       137
# Jan   Fishing&Hunting               134
# Jul   Surfing                       118
# Aug   Surfing                       107
# ...                                 ...
# Nov   Boating                         1
# Jun   Walking                         1
# Mar   Random activities               1
# May   Boating                         1
# Jul   Walking                         1
#
# [134 rows x 1 columns]

# %%
z.to_csv("mes_activ.csv")

# %%
b=df.groupby(['Country'])['Activity'].value_counts().to_frame()
b = b.rename(columns={"Activity": "Sharks_attacks"})
b.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                                      Sharks_attacks
# Country    Activity
# USA        Surfing                              674
#            Other Water Sports                   276
#            Swimming                             250
# AUSTRALIA  Surfing                              207
# USA        Bathing                              200
# ...                                             ...
# MADAGASCAR Shark related activities               1
#            Other Water Sports                     1
#            Fishing&Hunting                        1
#            Bathing                                1
# YEMEN      UnKnown                                1
#
# [444 rows x 1 columns]

# %%
b.to_csv("country_activ.csv")

# %%
df.duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 4223     True
# 4224     True
# 4225     True
# 4226    False
# 4227    False
# Length: 4215, dtype: bool

# %%
#data1 = data[["Date","New","Country","Name","Case Number","Age", "Fatal (Y/N)"]]
#data1.duplicated().value_counts()

# %%
#data.duplicated().value_counts()

# %%
null_cols = df.isnull().sum()
print(null_cols)
df["Fatal (Y/N)"].value_counts()
df["Fatal (Y/N)"].fillna("UNKNOWN", inplace=True)
df["Fatal (Y/N)"] = df["Fatal (Y/N)"].astype(str)
print(df.dtypes)
print(set(df["Fatal (Y/N)"]))
Fatal=[]
for e in df["Fatal (Y/N)"]:
    if re.search("N|n",e):
        a = re.sub("N|n","N",e)
        a = a.strip()
        Fatal.append(a)
    elif re.search("Y|F",e):
        a = re.sub("Y|F","Y",e)
        a = a.strip()
        Fatal.append(a)
    else:
        a = re.sub("nan|#VALUE!|UNKNOWN","UNKNOWN",e)
        a = a.strip()
        Fatal.append(a)
print(set(Fatal))
print(len(Fatal))
len(df["Fatal (Y/N)"])
df["Fatal (Y/N)"]=Fatal
# Out:
# Month            0
# Country          0
# Area           195
# Activity         0
# Fatal (Y/N)      7
# dtype: int64
# Month          object
# Country        object
# Area           object
# Activity       object
# Fatal (Y/N)    object
# dtype: object
# {'Y', ' N', 'UNKNOWN', 'N'}
# {'Y', 'UNKNOWN', 'N'}
# 4215

# %%
t=df.groupby(['Fatal (Y/N)'])['Activity'].value_counts().to_frame()
t = t.rename(columns={"Activity": "Sharks_attacks"})
t.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                                             Sharks_attacks
# Fatal (Y/N) Activity
# N           Surfing                                   1065
#             Fishing&Hunting                            684
#             Other Water Sports                         562
#             Swimming                                   413
#             Bathing                                    282
#             UnKnown                                    207
# Y           Swimming                                   188
#             Other Water Sports                         138
#             Accidents or natural disasters             104
#             Fishing&Hunting                             99
#             UnKnown                                     92
# N           Accidents or natural disasters              83
# Y           Surfing                                     68
# N           Shark related activities                    47
# Y           Bathing                                     36
# ...

# %%
t.to_csv("fatal_activ.csv")

# %%
w=df.groupby(['Fatal (Y/N)'])['Country'].value_counts().to_frame()
w = w.rename(columns={"Country": "Sharks_attacks_country"})
w.sort_values(by='Sharks_attacks_country', ascending=False)
display(w)
spain = 0
for e in df["Country"]:
    if e == "SPAIN":
        spain +=1
spain
# Out:
#                                Sharks_attacks_country
# Fatal (Y/N) Country
# N           USA                                  1626
#             AUSTRALIA                             598
#             SOUTH AFRICA                          369
#             BAHAMAS                                76
#             NEW ZEALAND                            67
# ...                                               ...
# Y           Sierra Leone                            1
#             THE BALKANS                             1
#             TRINIDAD & TOBAGO                       1
#             TURKEY                                  1
#             WESTERN SAMOA                           1
#
# [224 rows x 1 columns]
# 18

# %%
w.to_csv("fatal_country.csv")

# %%
data_filter = df[df['Country'] == "SPAIN"]
data_filter.head()
# Out:
#     Month Country                 Area         Activity Fatal (Y/N)
# 20    Jul   SPAIN    Alicante Province         Swimming           N
# 34    Jul   SPAIN       Canary Islands          Bathing           N
# 104   Dec   SPAIN  Grand Canary Island         Swimming           N
# 159   Aug   SPAIN             Alicante         Swimming           N
# 249   Dec   SPAIN              Granada  Fishing&Hunting           N

# %%
data_filter1=data_filter.groupby(['Fatal (Y/N)'])['Activity'].value_counts().to_frame()
data_filter1 = data_filter1.rename(columns={"Activity": "Sharks_attacks_Spain"})
data_filter1.sort_values(by='Sharks_attacks_Spain', ascending=False)
display(data_filter1)
# Out:
#                                             Sharks_attacks_Spain
# Fatal (Y/N) Activity
# N           Swimming                                           9
#             Other Water Sports                                 3
#             Bathing                                            2
#             Fishing&Hunting                                    2
#             Accidents or natural disasters                     1
#             Surfing                                            1

# %%
data_filter2 = data_filter1
data_filter2.reset_index(inplace = True)
data_filter2
# Out:
#   Fatal (Y/N)                        Activity  Sharks_attacks_Spain
# 0           N                        Swimming                     9
# 1           N              Other Water Sports                     3
# 2           N                         Bathing                     2
# 3           N                 Fishing&Hunting                     2
# 4           N  Accidents or natural disasters                     1
# 5           N                         Surfing                     1

# %%
data_filter2.to_csv("spain_fatal_activity.csv")

# %%
#data_filter2.plot('Activity', 'Sharks_attacks_Spain',color = 'red', linewidth=2)
#data_filter2.plot('Fatal (Y/N)', 'Sharks_attacks_Spain',color='blue', linewidth=2)

# %%
u=data_filter2.groupby(['Activity']).sum()
display(u.head())
#u = u.drop('Fatal (Y/N)', axis=1)
u.reset_index(inplace = True)
display(u)
u.describe()
# Out:
#                                 Sharks_attacks_Spain
# Activity
# Accidents or natural disasters                     1
# Bathing                                            2
# Fishing&Hunting                                    2
# Other Water Sports                                 3
# Surfing                                            1
#                          Activity  Sharks_attacks_Spain
# 0  Accidents or natural disasters                     1
# 1                         Bathing                     2
# 2                 Fishing&Hunting                     2
# 3              Other Water Sports                     3
# 4                         Surfing                     1
# 5                        Swimming                     9
#        Sharks_attacks_Spain
# count               6.00000
# mean                3.00000
# std                 3.03315
# min                 1.00000
# 25%                 1.25000
# 50%                 2.00000
# 75%                 2.75000
# ...

# %%
plt.pie(u['Sharks_attacks_Spain'],labels=u["Activity"])
plt.show()

# %%
u.plot("Activity",color = 'red', linewidth=2)
#data_filter2.plot('Fatal (Y/N)', 'Sharks_attacks_Spain',color='blue', linewidth=2)

# %%
#import geopandas as gpd

# %%
y.head()
y=y.groupby(['Country']).sum()
y.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                       Sharks_attacks
# Country
# USA                             1771
# AUSTRALIA                        731
# SOUTH AFRICA                     450
# PAPUA NEW GUINEA                 110
# BRAZIL                            95
# ...                              ...
# HONDURAS                           1
# GULF OF ADEN                       1
# SOUTH ATLANTIC OCEAN               1
# SOUTH CHINA SEA                    1
# ADMIRALTY ISLANDS                  1
#
# [139 rows x 1 columns]

# %%
y.T
y.reset_index(inplace = True)

# %%
print((y['Sharks_attacks'].sum()))
display(y)
y = y.sort_values(by='Sharks_attacks', ascending=False)
y
# Out:
# 4215
#                         Country  Sharks_attacks
# 0             ADMIRALTY ISLANDS               1
# 1                AMERICAN SAMOA               3
# 2    ANDAMAN / NICOBAR ISLANDAS               1
# 3                        ANGOLA               1
# 4                       ANTIGUA               1
# ..                          ...             ...
# 134                     VANUATU              11
# 135                   VENEZUELA               8
# 136                     VIETNAM              10
# 137               WESTERN SAMOA               1
# 138                       YEMEN               2
#
# [139 rows x 2 columns]
#                   Country  Sharks_attacks
# 133                   USA            1771
# 8               AUSTRALIA             731
# 110          SOUTH AFRICA             450
# 93       PAPUA NEW GUINEA             110
# 14                 BRAZIL              95
# ..                    ...             ...
# 46               HONDURAS               1
# ...

# %%
y.to_csv("shark_country.csv")

# %%
y.describe()
# Out:
#        Sharks_attacks
# count      139.000000
# mean        30.323741
# std        165.932115
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%          9.000000
# max       1771.000000

# %%
stats = y.describe().T
stats['IQR'] = stats['75%'] - stats['25%']
stats.head()
# Out:
#                 count       mean         std  min  25%  50%  75%     max  IQR
# Sharks_attacks  139.0  30.323741  165.932115  1.0  1.0  4.0  9.0  1771.0  8.0

# %%
outliers = pd.DataFrame(columns=y.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = y[(y[col] < lower) | 
  
                   (y[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#               Country         Outlier Sharks_attacks
# 133               USA  Sharks_attacks           1771
# 8           AUSTRALIA  Sharks_attacks            731
# 110      SOUTH AFRICA  Sharks_attacks            450
# 93   PAPUA NEW GUINEA  Sharks_attacks            110
# 14             BRAZIL  Sharks_attacks             95
# 10            BAHAMAS  Sharks_attacks             83
# 80        NEW ZEALAND  Sharks_attacks             78
# 69             MEXICO  Sharks_attacks             59
# 100           REUNION  Sharks_attacks             53
# 78      NEW CALEDONIA  Sharks_attacks             44
# ...

# %%
y.plot("Country","Sharks_attacks")

# %%
display(z.head())
z=z.groupby(['Month']).sum()
z.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                           Sharks_attacks
# Month Activity
# Apr   Surfing                         96
#       Fishing&Hunting                 58
#       Swimming                        49
#       Other Water Sports              38
#       UnKnown                         30
#        Sharks_attacks
# Month
# Jan               498
# Jul               468
# Aug               441
# Sep               409
# Jun               364
# Oct               327
# Apr               313
# Dec               300
# Mar               285
# May               276
# Nov               270
# Feb               264

# %%
z.reset_index(inplace = True)

# %%
print((z['Sharks_attacks'].sum()))
display(z)
z = z.sort_values(by='Sharks_attacks', ascending=False)
z
# Out:
# 4215
#    Month  Sharks_attacks
# 0    Apr             313
# 1    Aug             441
# 2    Dec             300
# 3    Feb             264
# 4    Jan             498
# 5    Jul             468
# 6    Jun             364
# 7    Mar             285
# 8    May             276
# 9    Nov             270
# 10   Oct             327
# 11   Sep             409
#    Month  Sharks_attacks
# 4    Jan             498
# 5    Jul             468
# 1    Aug             441
# 11   Sep             409
# 6    Jun             364
# 10   Oct             327
# 0    Apr             313
# 2    Dec             300
# 7    Mar             285
# 8    May             276
# 9    Nov             270
# 3    Feb             264

# %%
z.to_csv("shark_month.csv")

# %%
z.describe()
# Out:
#        Sharks_attacks
# count       12.000000
# mean       351.250000
# std         82.936038
# min        264.000000
# 25%        282.750000
# 50%        320.000000
# 75%        417.000000
# max        498.000000

# %%
stats = z.describe().T
stats['IQR'] = stats['75%'] - stats['25%']
stats.head()
# Out:
#                 count    mean        std    min     25%    50%    75%    max  \
# Sharks_attacks   12.0  351.25  82.936038  264.0  282.75  320.0  417.0  498.0
#
#                    IQR
# Sharks_attacks  134.25

# %%
outliersZ = pd.DataFrame(columns=z.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = z[(z[col] < lower) | 
  
                   (z[col] > upper)].copy()
    results['Outlier'] = col
    outliersZ = outliersZ.append(results)
outliersZ.head()
# Out:
# Empty DataFrame
# Columns: [Month, Outlier, Sharks_attacks]
# Index: []

# %%
z.plot("Month","Sharks_attacks")

# %%
display(b.head())
b=b.groupby(['Activity']).sum()
b.sort_values(by='Sharks_attacks', ascending=False)
# Out:
#                                                            Sharks_attacks
# Country                    Activity
# ADMIRALTY ISLANDS          UnKnown                                      1
# AMERICAN SAMOA             Accidents or natural disasters               1
#                            Random activities                            1
#                            Swimming                                     1
# ANDAMAN / NICOBAR ISLANDAS Bathing                                      1
#                                 Sharks_attacks
# Activity
# Surfing                                   1142
# Fishing&Hunting                            792
# Other Water Sports                         706
# Swimming                                   604
# UnKnown                                    322
# Bathing                                    321
# Accidents or natural disasters             187
# Shark related activities                    47
# Random activities                           41
# ...

# %%
b.reset_index(inplace = True)

# %%
print((b['Sharks_attacks'].sum()))
display(b)
b = b.sort_values(by='Sharks_attacks', ascending=False)
b
# Out:
# 4215
#                           Activity  Sharks_attacks
# 0   Accidents or natural disasters             187
# 1                          Bathing             321
# 2                          Boating              22
# 3                  Fishing&Hunting             792
# 4               Other Water Sports             706
# 5                Random activities              41
# 6         Shark related activities              47
# 7                  Stranger things              15
# 8                          Surfing            1142
# 9                         Swimming             604
# 10                         UnKnown             322
# 11                         Walking              16
#                           Activity  Sharks_attacks
# 8                          Surfing            1142
# 3                  Fishing&Hunting             792
# 4               Other Water Sports             706
# 9                         Swimming             604
# ...

# %%
b.to_csv("shark_activity.csv")

# %%
b.describe()
# Out:
#        Sharks_attacks
# count       12.000000
# mean       351.250000
# std        376.673267
# min         15.000000
# 25%         36.250000
# 50%        254.000000
# 75%        629.500000
# max       1142.000000

# %%
b.plot("Activity","Sharks_attacks")

# %%
stats = b.describe().T
stats['IQR'] = stats['75%'] - stats['25%']
stats.head()
# Out:
#                 count    mean         std   min    25%    50%    75%     max  \
# Sharks_attacks   12.0  351.25  376.673267  15.0  36.25  254.0  629.5  1142.0
#
#                    IQR
# Sharks_attacks  593.25

# %%
outliers = pd.DataFrame(columns=b.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = b[(b[col] < lower) | 
  
                   (b[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# Empty DataFrame
# Columns: [Activity, Outlier, Sharks_attacks]
# Index: []

# %%
plt.pie(b['Sharks_attacks'],labels=b["Activity"])
plt.show()

# %%
explode = [0.05 for i in range(len(df['Month'].value_counts().index.tolist()))]
plt.pie(z['Sharks_attacks'],explode=explode,labels=z["Month"])
plt.show()

# %%
data["Year"].value_counts().head(50)
set(data["Year"])
len(set(data["Year"]))
# Out:
# 66

# %%
drop_colN = ["Area","Name","Type","original order","Case Number","Sex ","Age","Injury","Time","Location","Species ","pdf","href formula","href","Case Number.1","Case Number.2","Investigator or Source","New","holaaa"]
dfN = data.drop(drop_colN,axis=1)
dfN
# Out:
#      Date  Year       Country  Activity Fatal (Y/N)
# 0     Sep  2016           USA   Surfing           N
# 1     Sep  2016           USA   Surfing           N
# 2     Sep  2016           USA   Surfing           N
# 3     Sep  2016     AUSTRALIA   Surfing           N
# 4     Sep  2016     AUSTRALIA   Surfing           N
# ...   ...   ...           ...       ...         ...
# 4223  Feb  1951     AUSTRALIA   Surfing           N
# 4224  Feb  1951     AUSTRALIA  Swimming           N
# 4225  Jan  1951  SOUTH AFRICA  Swimming           Y
# 4226  Jan  1951     AUSTRALIA   UnKnown           Y
# 4227  Jan  1951    NEW GUINEA   UnKnown           Y
#
# [4215 rows x 5 columns]

# %%
dfN
# Out:
#      Date  Year       Country  Activity Fatal (Y/N)
# 0     Sep  2016           USA   Surfing           N
# 1     Sep  2016           USA   Surfing           N
# 2     Sep  2016           USA   Surfing           N
# 3     Sep  2016     AUSTRALIA   Surfing           N
# 4     Sep  2016     AUSTRALIA   Surfing           N
# ...   ...   ...           ...       ...         ...
# 4223  Feb  1951     AUSTRALIA   Surfing           N
# 4224  Feb  1951     AUSTRALIA  Swimming           N
# 4225  Jan  1951  SOUTH AFRICA  Swimming           Y
# 4226  Jan  1951     AUSTRALIA   UnKnown           Y
# 4227  Jan  1951    NEW GUINEA   UnKnown           Y
#
# [4215 rows x 5 columns]

# %%
xN=dfN.groupby(['Year'])['Activity'].value_counts().to_frame()
xN
# Out:
#                                      Activity
# Year Activity
# 1951 Swimming                               8
#      Fishing&Hunting                        5
#      Surfing                                5
#      UnKnown                                4
#      Accidents or natural disasters         3
# ...                                       ...
# 2016 Bathing                               10
#      UnKnown                                6
#      Random activities                      3
#      Walking                                2
#      Shark related activities               1
#
# [557 rows x 1 columns]

# %%
xN = xN.rename(columns={"Activity": "Sharks_Year"})
xN = xN.sort_values(by=['Year',"Sharks_Year"], ascending=False)
display(xN)
# Out:
#                                      Sharks_Year
# Year Activity
# 2016 Surfing                                  33
#      Fishing&Hunting                          22
#      Swimming                                 15
#      Other Water Sports                       11
#      Bathing                                  10
# ...                                          ...
# 1951 Surfing                                   5
#      UnKnown                                   4
#      Accidents or natural disasters            3
#      Bathing                                   3
#      Other Water Sports                        3
#
# [557 rows x 1 columns]

# %%
xN.reset_index(inplace = True)

# %%
xN
# Out:
#      Year                        Activity  Sharks_Year
# 0    2016                         Surfing           33
# 1    2016                 Fishing&Hunting           22
# 2    2016                        Swimming           15
# 3    2016              Other Water Sports           11
# 4    2016                         Bathing           10
# ..    ...                             ...          ...
# 552  1951                         Surfing            5
# 553  1951                         UnKnown            4
# 554  1951  Accidents or natural disasters            3
# 555  1951                         Bathing            3
# 556  1951              Other Water Sports            3
#
# [557 rows x 3 columns]

# %%
xN1=xN.groupby(['Year']).sum()
xN1.sort_values(by='Year', ascending=False)
# Out:
#       Sharks_Year
# Year
# 2016          103
# 2015          139
# 2014          124
# 2013          122
# 2012          117
# ...           ...
# 1955           43
# 1954           42
# 1953           36
# 1952           29
# 1951           31
#
# [66 rows x 1 columns]

# %%
xN1.reset_index(inplace = True)

# %%
xN1 = xN1.sort_values(by='Year', ascending=False)
xN1
# Out:
#     Year  Sharks_Year
# 65  2016          103
# 64  2015          139
# 63  2014          124
# 62  2013          122
# 61  2012          117
# ..   ...          ...
# 4   1955           43
# 3   1954           42
# 2   1953           36
# 1   1952           29
# 0   1951           31
#
# [66 rows x 2 columns]

# %%
"""años=[]
for e in dfN["Year"]:
    if re.search("195+",e):
        s = re.sub("195+","1950's",e)
        años.append(s)"""
# Out:
# 'años=[]\nfor e in dfN["Year"]:\n    if re.search("195+",e):\n        s = re.sub("195+","1950\'s",e)\n        años.append(s)'

# %%
xN1.to_csv("atacks_year.csv")

# %%
xN1.describe()
# Out:
#               Year  Sharks_Year
# count    66.000000    66.000000
# mean   1983.500000    63.863636
# std      19.196354    31.414787
# min    1951.000000    25.000000
# 25%    1967.250000    38.250000
# 50%    1983.500000    54.500000
# 75%    1999.750000    92.000000
# max    2016.000000   139.000000
